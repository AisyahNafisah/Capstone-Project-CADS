# %% [markdown]
# <img src="images/cads-logo.png" style="height: 100px;" align=left>

# %% [markdown]
# # DA Capstone

# %% [markdown]
# 1. Create a team (2-3 people)
# 2. Perform the following:
#     1. **Data Wrangling - Cleaning & Merging**: Check and handle the existance of missing values, the type of variables, or integrity of data
#     2. **Exploratory Data Analysis**: Analyze data to summarize their main characteristics
#     3. **Feature Engineering**: Make new features or change the current features
#     4. **Feature Selection**: Choose the best features
#     5. **Queries** Use SQL to query the data

# %% [markdown]
# ## Submission Guideline
# The output expected at the end of this hackathon is:
# 1. One **Jupyter notebook** containing all analysis performed using Python.
# 2. One **PowerPoint** presentation containing the analysis results. Each group will be allocated 15-20 minutes (inclusive of Q&A) to present their analysis results to the class.
# 3. One **Final Dataset** - in csv format
#
# One zip file per group is to be uploaded on GDrive **by 2:30 pm of the last day**, including the jupyter notebook(s) and the powerpoint presentation indicating the names of all group members.
#
#
# ## Presentation Guideline
#
#
# **Note(s):**
# 1. Only **one submission** is required per group.
# 2. Include full details in your notebook and **report only important results** in your presentation.
# 3. Please only use Jupyter notebook (pandas) to clean the data (Do not clean manually using Excel)

# %% [markdown]
# ## Objective
# **Perform Exploratory Data Analysis for the Dataset Provided uisng Python, then load the data into a database using pandas and Solve the queries. The dataset is about customer purchasing history, and focused on determining potential customers.**
#
# You have been provided with information such as customers spending for last sevral years, the amount of money spent,Number of inactive months and so on

# %% [markdown]
# ## Data description
# - Below is the description of each feature available in the dataset
# <img src="images/MicrosoftTeams-image.png" style="height: 700px">

# %% [markdown]
# ##  Import necessary Packages

# %%
# Importing relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

#Your Code Here
from IPython.display import display

# %% [markdown]
# ### Load the Data into Pandas Dataframe

# %%
pwd
# Out:
# '/content'

# %%
# Load the data into data dataframe
#Your Code Here

cust_data = pd.read_csv("data/data.csv")
cust_data
# Out:
#       Potential_Customer    C_ID  ... Cust_Prop  Cust_Ann_Income
# 0                      1    9946  ...         H      $65,957.00
# 1                      1   87939  ...         U           $0.00
# 2                      0   88003  ...         U           $0.00
# 3                      1  188721  ...         U      $76,293.00
# 4                      1   88056  ...         H     $113,663.00
# ...                  ...     ...  ...       ...              ...
# 4464                   1  103926  ...         H      $29,081.00
# 4465                   1  103920  ...         U      $29,081.00
# 4466                   1  114820  ...         U           $0.00
# 4467                   1  103953  ...         U      $45,281.00
# 4468                   0  103979  ...         H      $41,165.00
#
# [4469 rows x 25 columns]

# %%
# View first 5 rows of the dataframe
#Your Code Here

cust_data.head(5)
# Out:
#    Potential_Customer    C_ID  ... Cust_Prop  Cust_Ann_Income
# 0                   1    9946  ...         H      $65,957.00
# 1                   1   87939  ...         U           $0.00
# 2                   0   88003  ...         U           $0.00
# 3                   1  188721  ...         U      $76,293.00
# 4                   1   88056  ...         H     $113,663.00
#
# [5 rows x 25 columns]

# %% [markdown]
# # <font color=green>Data Cleaning<font>
# Checking the existance of missing values, the type of variables, or integrity of data.

# %% [markdown]
# ### How big is the dataset? (number of rows, features and total datapoints)

# %%
cust_data.shape
# Out:
# (4469, 25)

# %%
cust_data.info() 
##Features == Column = 25
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4469 entries, 0 to 4468
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Potential_Customer        4469 non-null   int64
#  1   C_ID                      4469 non-null   int64
#  2   Cust_Last_Purchase        2149 non-null   object
#  3   Pur_3_years               4469 non-null   int64
#  4   Pur_5_years               4469 non-null   int64
#  5   Pur_3_years_Indirect      4469 non-null   int64
#  6   Pur_5_years_Indirect      4469 non-null   int64
#  7   Pur_latest                4469 non-null   object
#  8   Pur_3_years_Avg           4469 non-null   object
#  9   Pur_5_years_Avg           4469 non-null   object
#  10  Pur_3_years_Avg_Indirect  3642 non-null   object
#  11  InAct_Last                4469 non-null   int64
#  12  InAct_First               4469 non-null   int64
#  13  Ad_Res_1_year             4469 non-null   int64
# ...

# %% [markdown]
# ### What columns do we have?

# %%
#Your Code Here

cust_data.columns
# Out:
# Index(['Potential_Customer', 'C_ID', 'Cust_Last_Purchase', 'Pur_3_years',
#        'Pur_5_years', 'Pur_3_years_Indirect', 'Pur_5_years_Indirect',
#        'Pur_latest', 'Pur_3_years_Avg', 'Pur_5_years_Avg',
#        'Pur_3_years_Avg_Indirect', 'InAct_Last', 'InAct_First',
#        'Ad_Res_1_year', 'Ad_Res_3_Year', 'Ad_Res_5_Year', 'Ad_Res_Ind_1_Year',
#        'Ad_Res_Ind_3_Year', 'Ad_Res_Ind_5_Year', 'Status_Cust',
#        'Status_Latest_Ad', 'Age', 'Gender', 'Cust_Prop', 'Cust_Ann_Income'],
#       dtype='object')

# %% [markdown]
# ### What is the type of each column?

# %%
cust_data.dtypes ##before Change type astype

##Lists all datatypes of each column
# Out:
# Potential_Customer            int64
# C_ID                          int64
# Cust_Last_Purchase           object
# Pur_3_years                   int64
# Pur_5_years                   int64
# Pur_3_years_Indirect          int64
# Pur_5_years_Indirect          int64
# Pur_latest                   object
# Pur_3_years_Avg              object
# Pur_5_years_Avg              object
# Pur_3_years_Avg_Indirect     object
# InAct_Last                    int64
# InAct_First                   int64
# Ad_Res_1_year                 int64
# Ad_Res_3_Year                 int64
# Ad_Res_5_Year                 int64
# Ad_Res_Ind_1_Year             int64
# Ad_Res_Ind_3_Year             int64
# Ad_Res_Ind_5_Year             int64
# Status_Cust                  object
# Status_Latest_Ad              int64
# Age                         float64
# Gender                       object
# Cust_Prop                    object
# Cust_Ann_Income              object
# dtype: object

# %% [markdown]
# ### Why columns such as `Cust_Last_Purchase` are `object` while they should be `float64`?
#
# #### Notice Some features have Dollar AND Comma. Remove the dollar sign and comma from these features
#
# **Hint:** You can use `df.col=df.col.str.replace('OldSign', 'NewSign')`

# %%
#Your Code Here
cust_data.Cust_Last_Purchase=cust_data.Cust_Last_Purchase.str.replace(',', '')
cust_data.Cust_Last_Purchase=cust_data.Cust_Last_Purchase.str.replace('$', '')
cust_data.head(5)
# Out:
#    Potential_Customer    C_ID  ... Cust_Prop  Cust_Ann_Income
# 0                   1    9946  ...         H      $65,957.00
# 1                   1   87939  ...         U           $0.00
# 2                   0   88003  ...         U           $0.00
# 3                   1  188721  ...         U      $76,293.00
# 4                   1   88056  ...         H     $113,663.00
#
# [5 rows x 25 columns]

# %%
col_CustLastPurchase = {
    "Cust_Last_Purchase" : float
}

cust_data = cust_data.astype(col_CustLastPurchase)
cust_data.dtypes

##after change data astype object to float
# Out:
# Potential_Customer            int64
# C_ID                          int64
# Cust_Last_Purchase          float64
# Pur_3_years                   int64
# Pur_5_years                   int64
# Pur_3_years_Indirect          int64
# Pur_5_years_Indirect          int64
# Pur_latest                   object
# Pur_3_years_Avg              object
# Pur_5_years_Avg              object
# Pur_3_years_Avg_Indirect     object
# InAct_Last                    int64
# InAct_First                   int64
# Ad_Res_1_year                 int64
# Ad_Res_3_Year                 int64
# Ad_Res_5_Year                 int64
# Ad_Res_Ind_1_Year             int64
# Ad_Res_Ind_3_Year             int64
# Ad_Res_Ind_5_Year             int64
# Status_Cust                  object
# Status_Latest_Ad              int64
# Age                         float64
# Gender                       object
# Cust_Prop                    object
# Cust_Ann_Income              object
# dtype: object

# %% [markdown]
# ### Check data for duplicate rows

# %%
# Is there any duplicate in the data
#Your Code Here

cust_data.duplicated().any()
# Out:
# True

# %%
~cust_data.duplicated()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4464    False
# 4465    False
# 4466    False
# 4467    False
# 4468    False
# Length: 4469, dtype: bool

# %%
# Find the number of duplicates
#Your Code Here

cust_data.duplicated().sum()
# Out:
# 851

# %%
cust_data.loc[cust_data.duplicated()]
# Out:
#       Potential_Customer    C_ID  ...  Cust_Prop  Cust_Ann_Income
# 3618                   1    9946  ...          H      $65,957.00
# 3619                   1   87939  ...          U           $0.00
# 3620                   0   88003  ...          U           $0.00
# 3621                   1  188721  ...          U      $76,293.00
# 3622                   1   88056  ...          H     $113,663.00
# ...                  ...     ...  ...        ...              ...
# 4464                   1  103926  ...          H      $29,081.00
# 4465                   1  103920  ...          U      $29,081.00
# 4466                   1  114820  ...          U           $0.00
# 4467                   1  103953  ...          U      $45,281.00
# 4468                   0  103979  ...          H      $41,165.00
#
# [851 rows x 25 columns]

# %% [markdown]
# ### Remove duplicate rows
# **Hint:** Use `df=df.drop_duplicates()`

# %%
# Remove duplicates
#Your Code Here

cust_data=cust_data.drop_duplicates()

cust_data
# Out:
#       Potential_Customer    C_ID  ...  Cust_Prop  Cust_Ann_Income
# 0                      1    9946  ...          H      $65,957.00
# 1                      1   87939  ...          U           $0.00
# 2                      0   88003  ...          U           $0.00
# 3                      1  188721  ...          U      $76,293.00
# 4                      1   88056  ...          H     $113,663.00
# ...                  ...     ...  ...        ...              ...
# 3613                   1   87771  ...          H      $83,754.00
# 3614                   0   90077  ...          H      $83,754.00
# 3615                   0   94040  ...          U           $0.00
# 3616                   0   87871  ...          H      $71,618.00
# 3617                   1   87904  ...          U           $0.00
#
# [3618 rows x 25 columns]

# %% [markdown]
# ### Do we need `C_ID` in our analysis?

# %%
##C_ID as a unique/primary key
#Your Code Here
##cust_data.loc("C_ID")
counts = cust_data.nunique()
counts
# Out:
# Potential_Customer             2
# C_ID                        3618
# Cust_Last_Purchase            50
# Pur_3_years                   15
# Pur_5_years                   63
# Pur_3_years_Indirect          10
# Pur_5_years_Indirect          31
# Pur_latest                    59
# Pur_3_years_Avg              413
# Pur_5_years_Avg             1057
# Pur_3_years_Avg_Indirect     263
# InAct_Last                    24
# InAct_First                  121
# Ad_Res_1_year                 42
# Ad_Res_3_Year                 60
# Ad_Res_5_Year                131
# Ad_Res_Ind_1_Year             15
# Ad_Res_Ind_3_Year             25
# Ad_Res_Ind_5_Year             47
# Status_Cust                    6
# Status_Latest_Ad               2
# Age                           74
# Gender                         3
# Cust_Prop                      2
# Cust_Ann_Income             1897
# dtype: int64

# %% [markdown]
# ### Check whether the columns' types are accurate? if not handle them

# %%
#Your Code Here
cust_data.dtypes
# Out:
# Potential_Customer            int64
# C_ID                          int64
# Cust_Last_Purchase          float64
# Pur_3_years                   int64
# Pur_5_years                   int64
# Pur_3_years_Indirect          int64
# Pur_5_years_Indirect          int64
# Pur_latest                   object
# Pur_3_years_Avg              object
# Pur_5_years_Avg              object
# Pur_3_years_Avg_Indirect     object
# InAct_Last                    int64
# InAct_First                   int64
# Ad_Res_1_year                 int64
# Ad_Res_3_Year                 int64
# Ad_Res_5_Year                 int64
# Ad_Res_Ind_1_Year             int64
# Ad_Res_Ind_3_Year             int64
# Ad_Res_Ind_5_Year             int64
# Status_Cust                  object
# Status_Latest_Ad              int64
# Age                         float64
# Gender                       object
# Cust_Prop                    object
# Cust_Ann_Income              object
# dtype: object

# %%
##Remove string from cell
##data_change = ["Pur_latest","Pur_3_years_Avg","Pur_5_years_Avg","Pur_3_years_Avg_Indirect"] ##loop thru data type

cust_data.Pur_latest=cust_data.Pur_latest.str.replace(',', '')
cust_data.Pur_latest=cust_data.Pur_latest.str.replace('$', '')

cust_data.Pur_3_years_Avg=cust_data.Pur_3_years_Avg.str.replace(',', '')
cust_data.Pur_3_years_Avg=cust_data.Pur_3_years_Avg.str.replace('$', '')

cust_data.Pur_5_years_Avg=cust_data.Pur_5_years_Avg.str.replace(',', '')
cust_data.Pur_5_years_Avg=cust_data.Pur_5_years_Avg.str.replace('$', '')

cust_data.Pur_3_years_Avg_Indirect=cust_data.Pur_3_years_Avg_Indirect.str.replace(',', '')
cust_data.Pur_3_years_Avg_Indirect=cust_data.Pur_3_years_Avg_Indirect.str.replace('$', '')

cust_data.Cust_Ann_Income=cust_data.Cust_Ann_Income.str.replace(',', '')
cust_data.Cust_Ann_Income=cust_data.Cust_Ann_Income.str.replace('$', '')

# %%
cust_data.head()
# Out:
#    Potential_Customer    C_ID  ...  Cust_Prop  Cust_Ann_Income
# 0                   1    9946  ...          H        65957.00
# 1                   1   87939  ...          U            0.00
# 2                   0   88003  ...          U            0.00
# 3                   1  188721  ...          U        76293.00
# 4                   1   88056  ...          H       113663.00
#
# [5 rows x 25 columns]

# %%
col_ChangeType = {
    "Pur_latest" : float,
    "Pur_3_years_Avg" : float,
    "Pur_5_years_Avg" : float,
    "Pur_3_years_Avg_Indirect" : float,
    "Cust_Ann_Income" : float
}
cust_data = cust_data.astype(col_ChangeType)
cust_data.dtypes
# Out:
# Potential_Customer            int64
# C_ID                          int64
# Cust_Last_Purchase          float64
# Pur_3_years                   int64
# Pur_5_years                   int64
# Pur_3_years_Indirect          int64
# Pur_5_years_Indirect          int64
# Pur_latest                  float64
# Pur_3_years_Avg             float64
# Pur_5_years_Avg             float64
# Pur_3_years_Avg_Indirect    float64
# InAct_Last                    int64
# InAct_First                   int64
# Ad_Res_1_year                 int64
# Ad_Res_3_Year                 int64
# Ad_Res_5_Year                 int64
# Ad_Res_Ind_1_Year             int64
# Ad_Res_Ind_3_Year             int64
# Ad_Res_Ind_5_Year             int64
# Status_Cust                  object
# Status_Latest_Ad              int64
# Age                         float64
# Gender                       object
# Cust_Prop                    object
# Cust_Ann_Income             float64
# dtype: object

# %% [markdown]
# # <font color=green>Exploratory Data Analysis (EDA)<font>
# Checking the relationship of variables, summary of data, outliers, filling missing values etc.

# %% [markdown]
# ## Explore Categorical Variables

# %%
#Your Code Here
cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3618 entries, 0 to 3617
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Potential_Customer        3618 non-null   int64
#  1   C_ID                      3618 non-null   int64
#  2   Cust_Last_Purchase        1736 non-null   float64
#  3   Pur_3_years               3618 non-null   int64
#  4   Pur_5_years               3618 non-null   int64
#  5   Pur_3_years_Indirect      3618 non-null   int64
#  6   Pur_5_years_Indirect      3618 non-null   int64
#  7   Pur_latest                3618 non-null   float64
#  8   Pur_3_years_Avg           3618 non-null   float64
#  9   Pur_5_years_Avg           3618 non-null   float64
#  10  Pur_3_years_Avg_Indirect  2956 non-null   float64
#  11  InAct_Last                3618 non-null   int64
#  12  InAct_First               3618 non-null   int64
# ...

# %%
cust_data.head(1)
# Out:
#    Potential_Customer  C_ID  ...  Cust_Prop  Cust_Ann_Income
# 0                   1  9946  ...          H          65957.0
#
# [1 rows x 25 columns]

# %%
cust_data.Status_Cust=cust_data.Status_Cust.astype("category")
cust_data.Gender=cust_data.Gender.astype("category")
cust_data.Cust_Prop=cust_data.Cust_Prop.astype("category")

##change datatype into category

# %%
cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3618 entries, 0 to 3617
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Potential_Customer        3618 non-null   int64
#  1   C_ID                      3618 non-null   int64
#  2   Cust_Last_Purchase        1736 non-null   float64
#  3   Pur_3_years               3618 non-null   int64
#  4   Pur_5_years               3618 non-null   int64
#  5   Pur_3_years_Indirect      3618 non-null   int64
#  6   Pur_5_years_Indirect      3618 non-null   int64
#  7   Pur_latest                3618 non-null   float64
#  8   Pur_3_years_Avg           3618 non-null   float64
#  9   Pur_5_years_Avg           3618 non-null   float64
#  10  Pur_3_years_Avg_Indirect  2956 non-null   float64
#  11  InAct_Last                3618 non-null   int64
#  12  InAct_First               3618 non-null   int64
# ...

# %%
cust_data.describe(include="category")
# Out:
#        Status_Cust Gender Cust_Prop
# count         3618   3618      3618
# unique           6      3         2
# top              A      F         H
# freq          2146   1922      1981

# %%
cust_data.describe() ##default numerical data only
# Out:
#        Potential_Customer           C_ID  ...          Age  Cust_Ann_Income
# count         3618.000000    3618.000000  ...  2825.000000      3618.000000
# mean             0.479823   70151.997236  ...    59.018761     41608.894417
# std              0.499662   35499.154163  ...    16.900077     26127.991993
# min              0.000000      12.000000  ...     0.000000         0.000000
# 25%              0.000000   50146.500000  ...    47.000000     31385.750000
# 50%              0.000000   68694.000000  ...    60.000000     44284.500000
# 75%              1.000000   87779.500000  ...    73.000000     56508.000000
# max              1.000000  191672.000000  ...    87.000000    174305.000000
#
# [8 rows x 22 columns]

# %%
cust_data.describe(include="all") ## include categorical data type
# Out:
#         Potential_Customer           C_ID  ...  Cust_Prop  Cust_Ann_Income
# count          3618.000000    3618.000000  ...       3618      3618.000000
# unique                 NaN            NaN  ...          2              NaN
# top                    NaN            NaN  ...          H              NaN
# freq                   NaN            NaN  ...       1981              NaN
# mean              0.479823   70151.997236  ...        NaN     41608.894417
# std               0.499662   35499.154163  ...        NaN     26127.991993
# min               0.000000      12.000000  ...        NaN         0.000000
# 25%               0.000000   50146.500000  ...        NaN     31385.750000
# 50%               0.000000   68694.000000  ...        NaN     44284.500000
# 75%               1.000000   87779.500000  ...        NaN     56508.000000
# max               1.000000  191672.000000  ...        NaN    174305.000000
#
# [11 rows x 25 columns]

# %%
cust_data.Gender.unique()
# Out:
# ['F', 'M', 'U']
# Categories (3, object): ['F', 'M', 'U']

# %%
cust_data.Gender.value_counts()
# Out:
# F    1922
# M    1530
# U     166
# Name: Gender, dtype: int64

# %%
cust_data.Status_Cust.unique()
# Out:
# ['A', 'S', 'E', 'F', 'N', 'L']
# Categories (6, object): ['A', 'S', 'E', 'F', 'N', 'L']

# %%
cust_data.Status_Cust.value_counts()
# Out:
# A    2146
# S     964
# F     219
# N     207
# E      72
# L      10
# Name: Status_Cust, dtype: int64

# %%
cust_data.Cust_Prop.unique()
# Out:
# ['H', 'U']
# Categories (2, object): ['H', 'U']

# %%
cust_data.Cust_Prop.value_counts()
# Out:
# H    1981
# U    1637
# Name: Cust_Prop, dtype: int64

# %%
round(cust_data.Cust_Prop.value_counts(normalize=True)*100, 2)
# Out:
# H    54.75
# U    45.25
# Name: Cust_Prop, dtype: float64

# %%
round(cust_data.Status_Cust.value_counts(normalize=True)*100, 2)
# Out:
# A    59.31
# S    26.64
# F     6.05
# N     5.72
# E     1.99
# L     0.28
# Name: Status_Cust, dtype: float64

# %%
round(cust_data.Gender.value_counts(normalize=True)*100, 2)
# Out:
# F    53.12
# M    42.29
# U     4.59
# Name: Gender, dtype: float64

# %% [markdown]
# ### Explore Relationship Between Categorical & Target Variable
#
# **Hint**: use `sns.countplot()` plot

# %%
##Relationship between Gender and Customer Probability

sns.countplot(x ='Gender', hue='Cust_Prop', data = cust_data)
plt.show()

# %%
##Relationship between Customer Status and Gender

sns.countplot(x ='Status_Cust', hue='Gender', data = cust_data)
plt.show()

# %%
g = sns.catplot(x="Gender", hue="Status_Cust", col="Potential_Customer", col_order=[1, 0],
                data=cust_data, kind="count",
                height=8, aspect=1.0);

# %%
g._legend.texts[0].set_text("Active")
g._legend.texts[1].set_text("Inactive")
g._legend.texts[2].set_text("First Time")
g._legend.texts[3].set_text("Lapsing")
g._legend.texts[4].set_text("New")
g._legend.texts[5].set_text("Star")

# %%
g.fig

# %%
g.set_xticklabels(labels=['Female', 'Male', 'Unknown'])

# %%
g.fig

# %%
round(cust_data.Potential_Customer.value_counts(normalize=True)*100, 2)
# Out:
# 0    52.02
# 1    47.98
# Name: Potential_Customer, dtype: float64

# %%
g.fig.suptitle("Relationship of Gender and Customer Status as Potential Customer", y=1.05, fontsize=18)
# Out:
# Text(0.5, 1.05, 'Relationship of Gender and Customer Status as Potential Customer')

# %%
g.fig

# %%
sns.countplot(x="Status_Cust", hue="Potential_Customer", data=cust_data)

# %%
sns.countplot(x ='Gender', hue='Cust_Prop', data = cust_data)
plt.show()

# %% [markdown]
# ### Insight

# %% [markdown]
# The overview of the whole graph shows that there is lower potential of customers to purchase new house.
#
# Focusing on major demographic, female showcase having higher potential to make new purchase compared to male.
#
# Regarding the customers' status, customer having a star status have higher potential to make new purchase compared to other customer's status. Moreover, the is a major difference in weightage of customer's status between star and active.

# %% [markdown]
# ### Solution

# %%
cust_data.Status_Cust.unique()
# Out:
# ['A', 'S', 'E', 'F', 'N', 'L']
# Categories (6, object): ['A', 'S', 'E', 'F', 'N', 'L']

# %%
cust_data.Status_Cust=cust_data.Status_Cust.astype("string")

# %%
##cust_data.replace[to_replace, value]

# %%
##Data is too vague. To combine customer status others for small categories

#cust_data.loc[cust_data['Status_Cust'] == 'E', 'Status_Cust'] = "O"
#cust_data.loc[cust_data['Status_Cust'] == 'F', 'Status_Cust'] = "O"
#cust_data.loc[cust_data['Status_Cust'] == 'L', 'Status_Cust'] = "O"
#cust_data.loc[cust_data['Status_Cust'] == 'N', 'Status_Cust'] = "O"
#cust_data

new_dict = {'A':'A','S':'S','E':'Others','F':'Others','N':'Others','L':'Others'}
cust_data['Status_CustN'] = cust_data['Status_Cust'].replace(new_dict)
cust_data['Status_Cust'].unique()
# Out:
# <StringArray>
# ['A', 'S', 'E', 'F', 'N', 'L']
# Length: 6, dtype: string

# %%
cust_data
# Out:
#       Potential_Customer    C_ID  ...  Cust_Ann_Income  Status_CustN
# 0                      1    9946  ...          65957.0             A
# 1                      1   87939  ...              0.0             A
# 2                      0   88003  ...              0.0             S
# 3                      1  188721  ...          76293.0             A
# 4                      1   88056  ...         113663.0             S
# ...                  ...     ...  ...              ...           ...
# 3613                   1   87771  ...          83754.0             A
# 3614                   0   90077  ...          83754.0             S
# 3615                   0   94040  ...              0.0             A
# 3616                   0   87871  ...          71618.0             A
# 3617                   1   87904  ...              0.0             A
#
# [3618 rows x 26 columns]

# %%
sns.countplot(x="Status_CustN", hue="Potential_Customer", data=cust_data)
plt.show()

##how to remove F L and N?

# %%
sns.countplot(x ='Gender', hue='Cust_Prop', data = cust_data)
plt.show()

# %%
sns.countplot(x ='Potential_Customer', hue='Cust_Prop', data = cust_data)
plt.show()

# %% [markdown]
# ## Explore Numerical Variables
#
# **Hint**: use `sns.distplot()` and `sns.boxplot()`

# %%
#Your Code Here

##cust_data.sns.distplot()
cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3618 entries, 0 to 3617
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Potential_Customer        3618 non-null   int64
#  1   C_ID                      3618 non-null   int64
#  2   Cust_Last_Purchase        1736 non-null   float64
#  3   Pur_3_years               3618 non-null   int64
#  4   Pur_5_years               3618 non-null   int64
#  5   Pur_3_years_Indirect      3618 non-null   int64
#  6   Pur_5_years_Indirect      3618 non-null   int64
#  7   Pur_latest                3618 non-null   float64
#  8   Pur_3_years_Avg           3618 non-null   float64
#  9   Pur_5_years_Avg           3618 non-null   float64
#  10  Pur_3_years_Avg_Indirect  2956 non-null   float64
#  11  InAct_Last                3618 non-null   int64
#  12  InAct_First               3618 non-null   int64
# ...

# %%
cust_data.describe().T
# Out:
#                            count          mean  ...         75%       max
# Potential_Customer        3618.0      0.479823  ...      1.0000       1.0
# C_ID                      3618.0  70151.997236  ...  87779.5000  191672.0
# Cust_Last_Purchase        1736.0     14.557748  ...     20.0000     200.0
# Pur_3_years               3618.0      3.308734  ...      4.0000      15.0
# Pur_5_years               3618.0     11.018795  ...     15.0000      91.0
# Pur_3_years_Indirect      3618.0      1.909066  ...      3.0000       9.0
# Pur_5_years_Indirect      3618.0      5.887507  ...      9.0000      41.0
# Pur_latest                3618.0     15.267344  ...     20.0000     250.0
# Pur_3_years_Avg           3618.0     14.309536  ...     17.5000     260.0
# Pur_5_years_Avg           3618.0     11.913532  ...     14.7875     200.0
# Pur_3_years_Avg_Indirect  2956.0     13.582128  ...     16.6700     260.0
# InAct_Last                3618.0     17.934218  ...     20.0000      27.0
# ...

# %% [markdown]
# ###  Check the skewness and kurtosis of the variables? Is it normal? Document your process in the notebook of handling skewness and kurtosis

# %%
#Your Code Here
from scipy.stats import skew, kurtosis, norm

# %%
cust_data.skew()
# Out:
# Potential_Customer          0.080807
# C_ID                        1.026921
# Cust_Last_Purchase          4.966810
# Pur_3_years                 1.291322
# Pur_5_years                 2.079296
# Pur_3_years_Indirect        1.124769
# Pur_5_years_Indirect        1.287071
# Pur_latest                  6.660116
# Pur_3_years_Avg             7.913836
# Pur_5_years_Avg             6.756579
# Pur_3_years_Avg_Indirect    8.043963
# InAct_Last                 -0.808274
# InAct_First                 0.136455
# Ad_Res_1_year               2.788479
# Ad_Res_3_Year               0.321259
# Ad_Res_5_Year               0.401333
# Ad_Res_Ind_1_Year           0.943712
# Ad_Res_Ind_3_Year          -0.448007
# Ad_Res_Ind_5_Year           0.068045
# Status_Latest_Ad           -0.276913
# Age                        -0.406354
# Cust_Ann_Income             0.039826
# dtype: float64

# %%
g = sns.FacetGrid(cust_data, col = "Potential_Customer", sharex = False, sharey = False)
g.map(sns.distplot, "Cust_Last_Purchase")

# %%
#g = sns.FacetGrid(cust_data, row=["Potential_Customer",
                 # height=1.7, aspect=4,)
#g.map(sns.kdeplot, "Cust_Last_Purchase")

# %%
sns.distplot(cust_data.skew())

# %%
cust_data.kurtosis()
# Out:
# Potential_Customer           -1.994573
# C_ID                          3.044238
# Cust_Last_Purchase           51.839743
# Pur_3_years                   2.115542
# Pur_5_years                   8.114353
# Pur_3_years_Indirect          1.375351
# Pur_5_years_Indirect          2.046352
# Pur_latest                  101.756152
# Pur_3_years_Avg             145.520014
# Pur_5_years_Avg             112.633657
# Pur_3_years_Avg_Indirect    159.364308
# InAct_Last                    2.506173
# InAct_First                  -1.171029
# Ad_Res_1_year                10.520905
# Ad_Res_3_Year                 2.171718
# Ad_Res_5_Year                 0.235607
# Ad_Res_Ind_1_Year             7.304920
# Ad_Res_Ind_3_Year            -0.898953
# Ad_Res_Ind_5_Year            -0.813542
# Status_Latest_Ad             -1.924383
# Age                          -0.441947
# Cust_Ann_Income               0.438975
# dtype: float64

# %%
from statsmodels.graphics.gofplots import qqplot
fg = qqplot(cust_data["Cust_Ann_Income"], fit = True, line = '45')

# %% [markdown]
# ### Insight

# %% [markdown]
# ## Check the data for missing values?

# %%
#Your Code Here

# %%
# Count all NaN in each column
#Your Code Here
cust_data.isnull().sum()
# Out:
# Potential_Customer             0
# C_ID                           0
# Cust_Last_Purchase          1882
# Pur_3_years                    0
# Pur_5_years                    0
# Pur_3_years_Indirect           0
# Pur_5_years_Indirect           0
# Pur_latest                     0
# Pur_3_years_Avg                0
# Pur_5_years_Avg                0
# Pur_3_years_Avg_Indirect     662
# InAct_Last                     0
# InAct_First                    0
# Ad_Res_1_year                  0
# Ad_Res_3_Year                  0
# Ad_Res_5_Year                  0
# Ad_Res_Ind_1_Year              0
# Ad_Res_Ind_3_Year              0
# Ad_Res_Ind_5_Year              0
# Status_Cust                    0
# Status_Latest_Ad               0
# Age                          793
# Gender                         0
# Cust_Prop                      0
# Cust_Ann_Income                0
# Status_CustN                   0
# dtype: int64

# %%
# Count all NaN in the dataframe (both columns & Rows)
#Your Code Here
cust_data.isna().sum().sum()
# Out:
# 3337

# %% [markdown]
# ### How should we handle missing values? (Should we drop the rows? or impute them with values?)

# %%
#Find which columns have missing value
#Your Code Here
cust_data.columns[cust_data.isnull().any()].tolist()
# Out:
# ['Cust_Last_Purchase', 'Pur_3_years_Avg_Indirect', 'Age']

# %% [markdown]
# #### Handling Missing Value for `Cust_Last_Purchase` column

# %%
#Impute the missing values for Cust_Last_Purchase column
#Your Code Here
cust_data['Cust_Last_Purchase'].fillna(value=0)
# Out:
# 0        5.0
# 1       30.0
# 2        0.0
# 3       20.0
# 4        5.0
#         ...
# 3613    20.0
# 3614     0.0
# 3615     0.0
# 3616     0.0
# 3617    21.0
# Name: Cust_Last_Purchase, Length: 3618, dtype: float64

# %%
cust_data['Cust_Last_Purchase'].fillna(value=0).unique()
# Out:
# array([  5.  ,  30.  ,   0.  ,  20.  ,  10.  ,  13.  ,  25.  ,  26.  ,
#         14.  ,  15.  ,  12.  ,   4.  ,  40.  ,  11.  ,   8.  ,   6.  ,
#          2.  ,   3.  ,  21.  ,  23.  ,  16.  ,  24.  ,  17.  ,   7.  ,
#         50.  , 100.  ,  36.  ,  51.  ,  48.  ,  32.  ,  18.  ,   9.  ,
#         22.  ,  28.  ,   1.  ,  38.  ,  75.  ,  35.  ,  60.  ,  45.  ,
#         27.  , 200.  ,  18.25,  29.  ,  19.  ,  34.  ,  46.  ,  37.  ,
#         47.  ,  44.  ,  42.  ])

# %% [markdown]
# #### Handling Missing Value for `Pur_3_years_Avg_Indirect` column

# %%
#Impute the missing values for Pur_3_years_Avg_Indirect column
#Your Code Here
cust_data['Pur_3_years_Avg_Indirect'].fillna(value=0)
# Out:
# 0        7.50
# 1        0.00
# 2       14.67
# 3        0.00
# 4        4.00
#         ...
# 3613     0.00
# 3614    13.25
# 3615    12.50
# 3616    20.00
# 3617    11.00
# Name: Pur_3_years_Avg_Indirect, Length: 3618, dtype: float64

# %% [markdown]
# #### Handling Missing Value for `Age` column
#
# Changes for Age is omitted since it is not relevant to change missing value of age to 0.

# %%
#Impute the missing values for Age column
#Your Code Here
#cust_data.Age.unique()

#new_dict_age = {'Age':'A','S':'S','E':'Others','F':'Others','N':'Others','L':'Others'}

#cust_data['Age'].fillna(value=0).unique()

#cust_data['AgeRange'] = cust_data['Age' <= 87, 'Age'].replace(np.nan, 0)

# %%
cust_data.Age.unique()
# Out:
# array([71.,  7., 79., 73., 68., 67., 78., 48., 49., 63., 37., 45., 42.,
#        17., 76., 40., 80., nan, 77., 62., 43., 41., 27., 65.,  6., 69.,
#        35., 51., 85., 70., 50., 53., 66., 60., 72., 44., 55., 75., 59.,
#        81., 33., 36., 58., 57., 34., 87., 38.,  0., 52., 83., 25., 64.,
#        31., 30., 56., 47., 46., 82., 22., 74., 84., 61., 29., 39., 86.,
#        28., 54., 32., 26., 24., 23., 21., 19., 16., 14.])

# %%
#Replace the missing values(values lower than 14) for Age column 
#Your Code Here

cust_data.Age.median()
#cust_data['Age'].fillna(value=0)
# Out:
# 60.0

# %% [markdown]
# #### Handling Missing Value for `Cust_Ann_Income` column

# %%
#Your Code Here

cust_data.Cust_Ann_Income.unique()
# Out:
# array([65957.,     0., 76293., ..., 67646., 83754., 71618.])

# %% [markdown]
# #### Handling Missing Value for `Gender` column

# %%
#Replace the missing values for Gender column
#Your Code Here

# %%
#Your Code Here

# %%
#Your Code Here

# %% [markdown]
# ### Explore the Relationship between Numerical Variables & Target Variable

# %%
sns.boxplot(x='Potential_Customer',y='Pur_5_years',data=cust_data) ##boxplot -- Potential Customer no of purchases made in 5 years

# %%
cust_data['Potential_Customer'].value_counts()
# Out:
# 0    1882
# 1    1736
# Name: Potential_Customer, dtype: int64

# %%
sns.boxplot(x='Gender',y='Pur_3_years_Avg',data=cust_data) ##Potential Customer no of purchases made in 5 years

# %%
#SWARM HUE
target = 'Potential_Customer' #target variable
x = 'Pur_5_years'  #numerical variable

sns.set_style('whitegrid')
sns.swarmplot(x=target,y=x,data=cust_data,hue='Status_CustN',palette = "Set2",split=True)

# %%
## Swarm hue -- shows that star customer undergoes most number of purchases in 5 years compared to other customer status

# %%
#SWARM HUE
target = 'Gender' #target variable
x = 'Pur_5_years_Avg'  #numerical variable

sns.set_style('whitegrid')
sns.swarmplot(x=target,y=x,data=cust_data,palette = "Set2",split=True)

# %% [markdown]
# # <font color=green>Insights through data visualization<font>
#
# ### Create a chart to visualize potential customer breakdown

# %%
cust_data.dtypes
# Out:
# Potential_Customer             int64
# C_ID                           int64
# Cust_Last_Purchase           float64
# Pur_3_years                    int64
# Pur_5_years                    int64
# Pur_3_years_Indirect           int64
# Pur_5_years_Indirect           int64
# Pur_latest                   float64
# Pur_3_years_Avg              float64
# Pur_5_years_Avg              float64
# Pur_3_years_Avg_Indirect     float64
# InAct_Last                     int64
# InAct_First                    int64
# Ad_Res_1_year                  int64
# Ad_Res_3_Year                  int64
# Ad_Res_5_Year                  int64
# Ad_Res_Ind_1_Year              int64
# Ad_Res_Ind_3_Year              int64
# Ad_Res_Ind_5_Year              int64
# Status_Cust                   string
# Status_Latest_Ad               int64
# Age                          float64
# Gender                      category
# Cust_Prop                   category
# Cust_Ann_Income              float64
# ...

# %%
col_Potential_Customer = {
    "Potential_Customer" : object
}

cust_data = cust_data.astype(col_Potential_Customer)

# %%
cust_data.dtypes
# Out:
# Potential_Customer            object
# C_ID                           int64
# Cust_Last_Purchase           float64
# Pur_3_years                    int64
# Pur_5_years                    int64
# Pur_3_years_Indirect           int64
# Pur_5_years_Indirect           int64
# Pur_latest                   float64
# Pur_3_years_Avg              float64
# Pur_5_years_Avg              float64
# Pur_3_years_Avg_Indirect     float64
# InAct_Last                     int64
# InAct_First                    int64
# Ad_Res_1_year                  int64
# Ad_Res_3_Year                  int64
# Ad_Res_5_Year                  int64
# Ad_Res_Ind_1_Year              int64
# Ad_Res_Ind_3_Year              int64
# Ad_Res_Ind_5_Year              int64
# Status_Cust                   string
# Status_Latest_Ad               int64
# Age                          float64
# Gender                      category
# Cust_Prop                   category
# Cust_Ann_Income              float64
# ...

# %%
#cust_data.groupby('Potential_Customer').count()

#.plot.bar()

# %%
sns.countplot(x ='Potential_Customer', order=[ 1 , 0 ] , data = cust_data)

# %%
g = sns.FacetGrid(cust_data, col = "Potential_Customer", sharex = True, sharey = True)#create subframe
g.map(sns.distplot, "Age")

# %%
#Your Code Here
g = sns.FacetGrid(cust_data, col = "Potential_Customer", sharex = True, sharey = True)#create subframe
g.map(sns.distplot, "Cust_Ann_Income")

# %% [markdown]
# ### How is the Age of the customers distributed? Plot your Answer with the appropriate chart

# %%
g = sns.FacetGrid(cust_data, col = "Gender", sharex = False, sharey = False)#create subframe
g.map(sns.distplot, "Age");

# %%
g = sns.FacetGrid(cust_data, col = "Gender", sharex = False)
g.map(sns.boxplot, "Age", order = cust_data.Gender.unique());

# %%
cust_data.dtypes
# Out:
# Potential_Customer            object
# C_ID                           int64
# Cust_Last_Purchase           float64
# Pur_3_years                    int64
# Pur_5_years                    int64
# Pur_3_years_Indirect           int64
# Pur_5_years_Indirect           int64
# Pur_latest                   float64
# Pur_3_years_Avg              float64
# Pur_5_years_Avg              float64
# Pur_3_years_Avg_Indirect     float64
# InAct_Last                     int64
# InAct_First                    int64
# Ad_Res_1_year                  int64
# Ad_Res_3_Year                  int64
# Ad_Res_5_Year                  int64
# Ad_Res_Ind_1_Year              int64
# Ad_Res_Ind_3_Year              int64
# Ad_Res_Ind_5_Year              int64
# Status_Cust                   string
# Status_Latest_Ad               int64
# Age                          float64
# Gender                      category
# Cust_Prop                   category
# Cust_Ann_Income              float64
# ...

# %%
sns.distplot(cust_data["Age"], kde = True)

# %% [markdown]
# Left Skewed. Mean > Median

# %% [markdown]
# ### Explore the data by visualizing other features (such as customer annual income, distribution of gender)
# - Start by asking questions that can add value to the business (example: how did my customers behaving lately?)
# - Then continue by identifying which data are needed for the questions to be answered

# %%
g = sns.FacetGrid(cust_data, col = "Gender", sharex = False, sharey = False)#create subframe
g.map(sns.distplot, "Cust_Ann_Income");

# %%
g = sns.FacetGrid(cust_data, col = "Gender", sharex = False)
g.map(sns.boxplot, "Cust_Ann_Income")

# %% [markdown]
# ### What is the distribution of customers' last purchase

# %%
#Your Code Here
#x = np.linspace(0, 174305, 100000)
#plt.plot(x, cust_data(x))

# %%
cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3618 entries, 0 to 3617
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Potential_Customer        3618 non-null   object
#  1   C_ID                      3618 non-null   int64
#  2   Cust_Last_Purchase        1736 non-null   float64
#  3   Pur_3_years               3618 non-null   int64
#  4   Pur_5_years               3618 non-null   int64
#  5   Pur_3_years_Indirect      3618 non-null   int64
#  6   Pur_5_years_Indirect      3618 non-null   int64
#  7   Pur_latest                3618 non-null   float64
#  8   Pur_3_years_Avg           3618 non-null   float64
#  9   Pur_5_years_Avg           3618 non-null   float64
#  10  Pur_3_years_Avg_Indirect  2956 non-null   float64
#  11  InAct_Last                3618 non-null   int64
#  12  InAct_First               3618 non-null   int64
# ...

# %%
sns.distplot(cust_data["Cust_Last_Purchase"], kde = True)

# %%
cust_data.dtypes
# Out:
# Potential_Customer            object
# C_ID                           int64
# Cust_Last_Purchase           float64
# Pur_3_years                    int64
# Pur_5_years                    int64
# Pur_3_years_Indirect           int64
# Pur_5_years_Indirect           int64
# Pur_latest                   float64
# Pur_3_years_Avg              float64
# Pur_5_years_Avg              float64
# Pur_3_years_Avg_Indirect     float64
# InAct_Last                     int64
# InAct_First                    int64
# Ad_Res_1_year                  int64
# Ad_Res_3_Year                  int64
# Ad_Res_5_Year                  int64
# Ad_Res_Ind_1_Year              int64
# Ad_Res_Ind_3_Year              int64
# Ad_Res_Ind_5_Year              int64
# Status_Cust                   string
# Status_Latest_Ad               int64
# Age                          float64
# Gender                      category
# Cust_Prop                   category
# Cust_Ann_Income              float64
# ...

# %%
sns.distplot(cust_data['Cust_Last_Purchase'])
plt.show()

# %% [markdown]
# ### What's the Purchase amount pattern with regards to Gender

# %%
cust_data.head()
# Out:
#   Potential_Customer    C_ID  ...  Cust_Ann_Income  Status_CustN
# 0                  1    9946  ...          65957.0             A
# 1                  1   87939  ...              0.0             A
# 2                  0   88003  ...              0.0             S
# 3                  1  188721  ...          76293.0             A
# 4                  1   88056  ...         113663.0             S
#
# [5 rows x 26 columns]

# %%
sns.catplot(x="Gender", y="Pur_latest", kind = "strip", data = cust_data)

# %% [markdown]
# ### On average, which group of gender has the higher latest purchase amount?

# %%
#Your Code Here
mean_purchase = cust_data.groupby("Gender")['Pur_latest'].mean()
mean_purchase
plt.figure();
mean_purchase.plot.bar(title='Purchase Amount by Gender');
plt.xlabel('Gender');
plt.ylabel('mean_purchase')
# Out:
# Text(0, 0.5, 'mean_purchase')

# %% [markdown]
# ### What is the distribution of the status of our customers

# %%
sns.displot(cust_data["Status_Cust"])

# %%
#Your Code Here
sns.displot(cust_data["Status_CustN"])

# %% [markdown]
# ### What is the average number of purchase made in the last 3 years among different customer status

# %%
#Your Code Here
sns.barplot(x = 'Status_Cust',y = 'Pur_3_years',data = cust_data)
plt.show()

# %% [markdown]
# ### What is the average number of purchase made in the last 5 years among different customer status

# %%
cust_data.columns
# Out:
# Index(['Potential_Customer', 'C_ID', 'Cust_Last_Purchase', 'Pur_3_years',
#        'Pur_5_years', 'Pur_3_years_Indirect', 'Pur_5_years_Indirect',
#        'Pur_latest', 'Pur_3_years_Avg', 'Pur_5_years_Avg',
#        'Pur_3_years_Avg_Indirect', 'InAct_Last', 'InAct_First',
#        'Ad_Res_1_year', 'Ad_Res_3_Year', 'Ad_Res_5_Year', 'Ad_Res_Ind_1_Year',
#        'Ad_Res_Ind_3_Year', 'Ad_Res_Ind_5_Year', 'Status_Cust',
#        'Status_Latest_Ad', 'Age', 'Gender', 'Cust_Prop', 'Cust_Ann_Income',
#        'Status_CustN'],
#       dtype='object')

# %%
cust_data.groupby(['Pur_5_years_Avg', 'Status_CustN']).size().unstack()
# Out:
# Status_CustN       A  Others    S
# Pur_5_years_Avg
# 1.50             NaN     NaN  1.0
# 2.26             1.0     NaN  NaN
# 2.32             1.0     NaN  NaN
# 2.37             NaN     NaN  1.0
# 2.57             1.0     NaN  NaN
# ...              ...     ...  ...
# 62.50            1.0     NaN  NaN
# 100.00           NaN     1.0  NaN
# 111.11           1.0     NaN  NaN
# 138.75           1.0     NaN  NaN
# 200.00           NaN     1.0  NaN
#
# [1057 rows x 3 columns]

# %%
g = sns.catplot(x="Status_CustN", y="Pur_5_years_Avg", kind="bar", data=cust_data)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Relationship Status Customer and Average Purchase within 5 years')
plt.show()

# %% [markdown]
# ### What is the distribution of the inactive number of months since last purchase?

# %%
from scipy.stats import norm

# %%
cust_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3618 entries, 0 to 3617
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Potential_Customer        3618 non-null   object
#  1   C_ID                      3618 non-null   int64
#  2   Cust_Last_Purchase        1736 non-null   float64
#  3   Pur_3_years               3618 non-null   int64
#  4   Pur_5_years               3618 non-null   int64
#  5   Pur_3_years_Indirect      3618 non-null   int64
#  6   Pur_5_years_Indirect      3618 non-null   int64
#  7   Pur_latest                3618 non-null   float64
#  8   Pur_3_years_Avg           3618 non-null   float64
#  9   Pur_5_years_Avg           3618 non-null   float64
#  10  Pur_3_years_Avg_Indirect  2956 non-null   float64
#  11  InAct_Last                3618 non-null   int64
#  12  InAct_First               3618 non-null   int64
# ...

# %%
col_ChangeType = {
    "Potential_Customer" : object,
    "C_ID" : object}
cust_df = cust_data.astype(col_ChangeType)
cust_df.dtypes
# Out:
# Potential_Customer            object
# C_ID                          object
# Cust_Last_Purchase           float64
# Pur_3_years                    int64
# Pur_5_years                    int64
# Pur_3_years_Indirect           int64
# Pur_5_years_Indirect           int64
# Pur_latest                   float64
# Pur_3_years_Avg              float64
# Pur_5_years_Avg              float64
# Pur_3_years_Avg_Indirect     float64
# InAct_Last                     int64
# InAct_First                    int64
# Ad_Res_1_year                  int64
# Ad_Res_3_Year                  int64
# Ad_Res_5_Year                  int64
# Ad_Res_Ind_1_Year              int64
# Ad_Res_Ind_3_Year              int64
# Ad_Res_Ind_5_Year              int64
# Status_Cust                   string
# Status_Latest_Ad               int64
# Age                          float64
# Gender                      category
# Cust_Prop                   category
# Cust_Ann_Income              float64
# ...

# %%
cust_df.describe().T
# Out:
#                            count          mean  ...         75%       max
# Cust_Last_Purchase        1736.0     14.557748  ...     20.0000     200.0
# Pur_3_years               3618.0      3.308734  ...      4.0000      15.0
# Pur_5_years               3618.0     11.018795  ...     15.0000      91.0
# Pur_3_years_Indirect      3618.0      1.909066  ...      3.0000       9.0
# Pur_5_years_Indirect      3618.0      5.887507  ...      9.0000      41.0
# Pur_latest                3618.0     15.267344  ...     20.0000     250.0
# Pur_3_years_Avg           3618.0     14.309536  ...     17.5000     260.0
# Pur_5_years_Avg           3618.0     11.913532  ...     14.7875     200.0
# Pur_3_years_Avg_Indirect  2956.0     13.582128  ...     16.6700     260.0
# InAct_Last                3618.0     17.934218  ...     20.0000      27.0
# InAct_First               3618.0     73.807352  ...    111.0000     260.0
# Ad_Res_1_year             3618.0     13.031786  ...     13.0000      49.0
# ...

# %%
cust_df.skew()
# Out:
# Potential_Customer          0.080807
# C_ID                        1.026921
# Cust_Last_Purchase          4.966810
# Pur_3_years                 1.291322
# Pur_5_years                 2.079296
# Pur_3_years_Indirect        1.124769
# Pur_5_years_Indirect        1.287071
# Pur_latest                  6.660116
# Pur_3_years_Avg             7.913836
# Pur_5_years_Avg             6.756579
# Pur_3_years_Avg_Indirect    8.043963
# InAct_Last                 -0.808274
# InAct_First                 0.136455
# Ad_Res_1_year               2.788479
# Ad_Res_3_Year               0.321259
# Ad_Res_5_Year               0.401333
# Ad_Res_Ind_1_Year           0.943712
# Ad_Res_Ind_3_Year          -0.448007
# Ad_Res_Ind_5_Year           0.068045
# Status_Latest_Ad           -0.276913
# Age                        -0.406354
# Cust_Ann_Income             0.039826
# dtype: float64

# %% [markdown]
# If a skewness value of greater than 1 is obtained in either direction (positive/negative), we say that the distribution is highly skewed. A skewness value of 0 represents a perfectly symmetric distribution, which in the case of real-world data is close to impossible to observe.
#
# We can say that the purchase average of 5 years is highly skewed in right direction, which is positive skewed.

# %%
cust_df.kurtosis()
# Out:
# Potential_Customer           -1.994573
# C_ID                          3.044238
# Cust_Last_Purchase           51.839743
# Pur_3_years                   2.115542
# Pur_5_years                   8.114353
# Pur_3_years_Indirect          1.375351
# Pur_5_years_Indirect          2.046352
# Pur_latest                  101.756152
# Pur_3_years_Avg             145.520014
# Pur_5_years_Avg             112.633657
# Pur_3_years_Avg_Indirect    159.364308
# InAct_Last                    2.506173
# InAct_First                  -1.171029
# Ad_Res_1_year                10.520905
# Ad_Res_3_Year                 2.171718
# Ad_Res_5_Year                 0.235607
# Ad_Res_Ind_1_Year             7.304920
# Ad_Res_Ind_3_Year            -0.898953
# Ad_Res_Ind_5_Year            -0.813542
# Status_Latest_Ad             -1.924383
# Age                          -0.441947
# Cust_Ann_Income               0.438975
# dtype: float64

# %% [markdown]
# Kurtosis is a measure of tailedness, i.e. how heavily the data is saturated in the tails of the distribution as opposed to its center. Visually, kurtosis manifests as either a shorter or taller distribution along the y-axis. This appearance is mainly due to the tails being fatter or thinner respectively.
#
# Kurtosis uses the Normal distribution as a point of reference, i.e. it measures how much thinner/fatter the tails of a distribution are compared to a Normal distribution.
#
# If the kurtosis is negative ( <0 ), we say the distribution is platykurtic. This means its tails are thinner than that of a Normal distribution. Visually, platykurtic distributions appear shorter in height compared to a Normal distribution.
# If the kurtosis value is zero ( =0 ), we say the distribution is mesokurtic. This means the thickness of its tails are identical/similar to that of a Normal distribution.
# If the kurtosis value is positive ( >0 ), we say the distribution is leptokurtic. This means its tails are thicker than that of a Normal distribution. Visually, leptokurtic distributions appear taller in height compared to a Normal distribution.
#
# We can see that the kurtosis of inactive number of months since last purchase is high, which it appears higher compared to normal-bell shaped graph.

# %%
sns.distplot(cust_df['InAct_Last'], label='Distr Inactive Last Purchase')

x=np.linspace(min(cust_df['InAct_Last'])-1, max(cust_df['InAct_Last'])+1, 2000)
y=norm.pdf(x,loc=np.mean(cust_df['InAct_Last']), scale=cust_df['InAct_Last'].std(ddof=1))
plt.plot(x,y, label='Normal Distribution')
plt.legend(loc='upper right');

# %%
sns.boxplot(cust_df['InAct_Last']);

# %% [markdown]
# This shows that Inactive Number of Months Since Last Purchase of Customer distribution is not normal, because mean is not at center. There are a few outliers.

# %% [markdown]
# ### What is the average number of purchase made in the last 3 years among different gender

# %%
g = sns.catplot(x="Gender", y="Pur_3_years_Avg", kind="bar", data=cust_df)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Relationship Gender and Average Purchase within 3 years')
plt.show()

# %% [markdown]
# ### Check the distribution of customers who responded to ads in past 5 years with By Gender

# %% [markdown]
# #### Plot By gender

# %%
cust_df.groupby('Gender')['Ad_Res_5_Year'].describe().unstack()
# Out:
#        Gender
# count  F         1922.000000
#        M         1530.000000
#        U          166.000000
# mean   F           49.517690
#        M           49.779085
#        U           49.204819
# std    F           23.356236
#        M           22.521690
#        U           20.204865
# min    F            7.000000
#        M            8.000000
#        U            7.000000
# 25%    F           30.000000
#        M           31.000000
#        U           34.000000
# 50%    F           50.000000
#        M           51.000000
#        U           50.000000
# 75%    F           66.000000
#        M           66.000000
#        U           65.000000
# max    F          157.000000
#        M          137.000000
#        U          130.000000
# dtype: float64

# %%
cust_df.groupby('Gender')['Ad_Res_5_Year'].skew()
# Out:
# Gender
# F    0.446192
# M    0.353361
# U    0.200307
# Name: Ad_Res_5_Year, dtype: float64

# %%
cust_df['Ad_Res_5_Year'].kurtosis()
# Out:
# 0.23560739297598365

# %%
cust_df['Ad_Res_5_Year'].hist(by=cust_df['Gender'])
plt.xlabel('Count')
plt.ylabel('Ad_Res_5_Year')
plt.show()

# %%
cust_df.groupby('Gender')['Ad_Res_5_Year'].apply(lambda x: sns.kdeplot(x, label = x.name))
plt.xlabel('Gender')
plt.ylabel('Ad_Res_5_Year')
plt.suptitle("Distribution of Ads Response within 5 years by Gender")
plt.show()

# %%
sns.kdeplot(
   data=cust_df, x="Ad_Res_5_Year", hue="Gender",
   fill=True, common_norm=False, palette="Pastel1",
   alpha=.5, linewidth=0,
)

# %%
sns.catplot(x="Gender", y="Ad_Res_5_Year", kind="box", data=cust_df)

# %%
ordered_gender = cust_df.Gender.value_counts().index
g = sns.FacetGrid(cust_df, row="Gender", row_order=ordered_gender,
                  height=1.7, aspect=4,)
g.map(sns.kdeplot, "Ad_Res_5_Year")

# %% [markdown]
# #### Plot By Customer Status

# %%
cust_df.groupby('Status_Cust')['Ad_Res_5_Year'].describe().unstack()
# Out:
#        Status_Cust
# count  A              2146.000000
#        E                72.000000
#        F               219.000000
#        L                10.000000
#        N               207.000000
#        S               964.000000
# mean   A                49.826654
#        E                28.444444
#        F                16.634703
#        L                60.100000
#        N                19.937198
#        S                64.477178
# std    A                19.550467
#        E                17.025986
#        F                11.441670
#        L                20.069047
#        N                 9.654262
#        S                18.573043
# min    A                16.000000
#        E                 7.000000
#        F                 9.000000
#        L                22.000000
#        N                10.000000
#        S                22.000000
# 25%    A                34.000000
#        E                13.750000
#        F                13.000000
# ...

# %%
cust_df.groupby('Status_Cust')['Ad_Res_5_Year'].skew()
# Out:
# Status_Cust
# A    0.721218
# E    0.737182
# F    4.369969
# L   -0.648065
# N    5.529933
# S    0.700352
# Name: Ad_Res_5_Year, dtype: float64

# %%
cust_df['Ad_Res_5_Year'].hist(by=cust_df['Status_Cust'])
plt.xlabel('Count')
plt.ylabel('Ad_Res_5_Year')
plt.show()

# %%
#Your Code Here
ordered_cust = cust_df.Status_Cust.value_counts().index
g = sns.FacetGrid(cust_df, row="Status_Cust", row_order=ordered_cust,
                  height=1.7, aspect=4,)
g.map(sns.kdeplot, "Ad_Res_5_Year")

# %%
sns.catplot(x="Status_Cust", y="Ad_Res_5_Year", kind="box", data=cust_df)

# %% [markdown]
# #### Plot By House Ownership

# %%
cust_df.groupby('Cust_Prop')['Ad_Res_5_Year'].describe()
# Out:
#             count       mean        std   min   25%   50%   75%    max
# Cust_Prop
# H          1981.0  49.395255  22.461702  10.0  31.0  51.0  65.0  147.0
# U          1637.0  49.878436  23.346974   7.0  30.0  50.0  67.0  157.0

# %%
cust_df.groupby('Cust_Prop')['Ad_Res_5_Year'].skew()
# Out:
# Cust_Prop
# H    0.373925
# U    0.428374
# Name: Ad_Res_5_Year, dtype: float64

# %%
cust_df['Ad_Res_5_Year'].hist(by=cust_df['Cust_Prop'])
plt.xlabel('Count')
plt.ylabel('Ad_Res_5_Year')
plt.show()

# %%
#Your Code Here
ordered_prop = cust_df.Cust_Prop.value_counts().index
g = sns.FacetGrid(cust_df, row="Cust_Prop", row_order=ordered_prop,
                  height=1.7, aspect=4,)
g.map(sns.kdeplot, "Ad_Res_5_Year")

# %%
sns.catplot(x="Cust_Prop", y="Ad_Res_5_Year", kind="box", data=cust_df)

# %% [markdown]
# #### Summarize your findings - what have you learned from your insights?

# %%
#Your Code Here

# %%
#Your Code Here

# %% [markdown]
# # <font color=green>Feature Enginearing<font>
#
# ### We have too many Features? Do you think you can make some high level features?
#
# For example: Instead of three variables for number of ads responded by customer? why not create a single variable which shows ads responded in last three years

# %%
#Your Code Here

cust_data_new = cust_data.copy()

cust_data_new
# Out:
#      Potential_Customer    C_ID  ...  Cust_Ann_Income  Status_CustN
# 0                     1    9946  ...          65957.0             A
# 1                     1   87939  ...              0.0             A
# 2                     0   88003  ...              0.0             S
# 3                     1  188721  ...          76293.0             A
# 4                     1   88056  ...         113663.0             S
# ...                 ...     ...  ...              ...           ...
# 3613                  1   87771  ...          83754.0             A
# 3614                  0   90077  ...          83754.0             S
# 3615                  0   94040  ...              0.0             A
# 3616                  0   87871  ...          71618.0             A
# 3617                  1   87904  ...              0.0             A
#
# [3618 rows x 26 columns]

# %%
## Sum of Purchase_3_yrs

sum_column = cust_data_new["Pur_3_years"] + cust_data_new["Pur_3_years_Indirect"]
cust_data_new["Total_Pur_3_years"] = sum_column

cust_data_new[["Pur_3_years","Pur_3_years_Indirect","Total_Pur_3_years"]]
# Out:
#       Pur_3_years  Pur_3_years_Indirect  Total_Pur_3_years
# 0               2                     2                  4
# 1               1                     0                  1
# 2               5                     3                  8
# 3               1                     0                  1
# 4               3                     2                  5
# ...           ...                   ...                ...
# 3613            2                     0                  2
# 3614            7                     4                 11
# 3615            7                     6                 13
# 3616            1                     1                  2
# 3617            3                     1                  4
#
# [3618 rows x 3 columns]

# %%
cust_data_new.columns
# Out:
# Index(['Potential_Customer', 'C_ID', 'Cust_Last_Purchase', 'Pur_3_years',
#        'Pur_5_years', 'Pur_3_years_Indirect', 'Pur_5_years_Indirect',
#        'Pur_latest', 'Pur_3_years_Avg', 'Pur_5_years_Avg',
#        'Pur_3_years_Avg_Indirect', 'InAct_Last', 'InAct_First',
#        'Ad_Res_1_year', 'Ad_Res_3_Year', 'Ad_Res_5_Year', 'Ad_Res_Ind_1_Year',
#        'Ad_Res_Ind_3_Year', 'Ad_Res_Ind_5_Year', 'Status_Cust',
#        'Status_Latest_Ad', 'Age', 'Gender', 'Cust_Prop', 'Cust_Ann_Income',
#        'Status_CustN', 'Total_Pur_3_years'],
#       dtype='object')

# %%
#Your Code Here

sum_column = cust_data_new["Pur_5_years"] + cust_data_new["Pur_5_years_Indirect"]
cust_data_new["Total_Pur_5_years"] = sum_column

cust_data_new[["Pur_5_years","Pur_5_years_Indirect","Total_Pur_5_years"]]
# Out:
#       Pur_5_years  Pur_5_years_Indirect  Total_Pur_5_years
# 0              17                     4                 21
# 1               7                     3                 10
# 2              12                     5                 17
# 3              11                     3                 14
# 4              15                     7                 22
# ...           ...                   ...                ...
# 3613            6                     1                  7
# 3614           31                    21                 52
# 3615           13                     8                 21
# 3616           11                     7                 18
# 3617           13                     6                 19
#
# [3618 rows x 3 columns]

# %%
sum_column = cust_data_new["Ad_Res_1_year"] + cust_data_new["Ad_Res_Ind_1_Year"]
cust_data_new["Total_Ad_Res_1_year"] = sum_column

cust_data_new[["Ad_Res_1_year","Ad_Res_Ind_1_Year","Total_Ad_Res_1_year"]]
# Out:
#       Ad_Res_1_year  Ad_Res_Ind_1_Year  Total_Ad_Res_1_year
# 0                32                  3                   35
# 1                13                  6                   19
# 2                14                  6                   20
# 3                17                  8                   25
# 4                13                  6                   19
# ...             ...                ...                  ...
# 3613             13                  6                   19
# 3614             13                  6                   19
# 3615             16                  7                   23
# 3616             11                  6                   17
# 3617             13                  6                   19
#
# [3618 rows x 3 columns]

# %%
cust_data_new.columns
# Out:
# Index(['Potential_Customer', 'C_ID', 'Cust_Last_Purchase', 'Pur_3_years',
#        'Pur_5_years', 'Pur_3_years_Indirect', 'Pur_5_years_Indirect',
#        'Pur_latest', 'Pur_3_years_Avg', 'Pur_5_years_Avg',
#        'Pur_3_years_Avg_Indirect', 'InAct_Last', 'InAct_First',
#        'Ad_Res_1_year', 'Ad_Res_3_Year', 'Ad_Res_5_Year', 'Ad_Res_Ind_1_Year',
#        'Ad_Res_Ind_3_Year', 'Ad_Res_Ind_5_Year', 'Status_Cust',
#        'Status_Latest_Ad', 'Age', 'Gender', 'Cust_Prop', 'Cust_Ann_Income',
#        'Status_CustN', 'Total_Pur_3_years', 'Total_Pur_5_years',
#        'Total_Ad_Res_1_year'],
#       dtype='object')

# %%
sum_column = cust_data_new["Ad_Res_3_Year"] + cust_data_new["Ad_Res_Ind_3_Year"]
cust_data_new["Total_Ad_Res_3_year"] = sum_column

cust_data_new[["Ad_Res_3_Year","Ad_Res_Ind_3_Year","Total_Ad_Res_3_year"]]
# Out:
#       Ad_Res_3_Year  Ad_Res_Ind_3_Year  Total_Ad_Res_3_year
# 0                48                 12                   60
# 1                35                  6                   41
# 2                35                 17                   52
# 3                38                  8                   46
# 4                28                 12                   40
# ...             ...                ...                  ...
# 3613             34                  6                   40
# 3614             32                 17                   49
# 3615             36                 18                   54
# 3616             31                 15                   46
# 3617             34                 16                   50
#
# [3618 rows x 3 columns]

# %%
sum_column = cust_data_new["Ad_Res_5_Year"] + cust_data_new["Ad_Res_Ind_5_Year"]
cust_data_new["Total_Ad_Res_5_year"] = sum_column

cust_data_new[["Ad_Res_5_Year","Ad_Res_Ind_5_Year","Total_Ad_Res_5_year"]]
# Out:
#       Ad_Res_5_Year  Ad_Res_Ind_5_Year  Total_Ad_Res_5_year
# 0                73                 16                   89
# 1                55                 22                   77
# 2                53                 22                   75
# 3                71                 33                  104
# 4                63                 24                   87
# ...             ...                ...                  ...
# 3613             47                 17                   64
# 3614             88                 35                  123
# 3615             57                 24                   81
# 3616             61                 25                   86
# 3617             70                 29                   99
#
# [3618 rows x 3 columns]

# %%
cust_data_new.head()
# Out:
#   Potential_Customer    C_ID  ...  Total_Ad_Res_3_year  Total_Ad_Res_5_year
# 0                  1    9946  ...                   60                   89
# 1                  1   87939  ...                   41                   77
# 2                  0   88003  ...                   52                   75
# 3                  1  188721  ...                   46                  104
# 4                  1   88056  ...                   40                   87
#
# [5 rows x 31 columns]

# %%
cust_data_new = cust_data_new.drop(['Pur_3_years', 'Pur_5_years','Pur_3_years_Indirect','Pur_5_years_Indirect','Ad_Res_1_year','Ad_Res_3_Year','Ad_Res_5_Year','Ad_Res_Ind_1_Year','Ad_Res_Ind_3_Year','Ad_Res_Ind_5_Year'], axis = 1)

# %%
cust_data_new.head()
# Out:
#   Potential_Customer    C_ID  ...  Total_Ad_Res_3_year  Total_Ad_Res_5_year
# 0                  1    9946  ...                   60                   89
# 1                  1   87939  ...                   41                   77
# 2                  0   88003  ...                   52                   75
# 3                  1  188721  ...                   46                  104
# 4                  1   88056  ...                   40                   87
#
# [5 rows x 21 columns]

# %% [markdown]
# # <font color=green>Feature Selection<font>
#
# ### Check the correlation among the variables

# %%
#Your Code Here

cust_data_new.corr(method = "pearson")
# Out:
#                               C_ID  ...  Total_Ad_Res_5_year
# C_ID                      1.000000  ...            -0.166728
# Cust_Last_Purchase       -0.037272  ...            -0.087785
# Pur_latest               -0.028949  ...            -0.112142
# Pur_3_years_Avg          -0.007806  ...            -0.080094
# Pur_5_years_Avg          -0.034537  ...            -0.230799
# Pur_3_years_Avg_Indirect  0.002317  ...            -0.079484
# InAct_Last                0.011923  ...            -0.214102
# InAct_First              -0.033071  ...             0.878249
# Status_Latest_Ad         -0.046653  ...             0.562739
# Age                      -0.031225  ...             0.218280
# Cust_Ann_Income           0.000167  ...            -0.006659
# Total_Pur_3_years        -0.038032  ...             0.293233
# Total_Pur_5_years        -0.077321  ...             0.799342
# Total_Ad_Res_1_year      -0.343865  ...             0.493455
# ...

# %%
cust_data_new[["Total_Ad_Res_3_year","Total_Pur_3_years","Pur_3_years_Avg"]].corr()["Total_Pur_3_years"][:]
# Out:
# Total_Ad_Res_3_year    0.504730
# Total_Pur_3_years      1.000000
# Pur_3_years_Avg       -0.342615
# Name: Total_Pur_3_years, dtype: float64

# %%
cust_data_new[["Total_Ad_Res_3_year","Total_Pur_3_years","Pur_3_years_Avg"]].corr()
# Out:
#                      Total_Ad_Res_3_year  Total_Pur_3_years  Pur_3_years_Avg
# Total_Ad_Res_3_year             1.000000           0.504730        -0.024606
# Total_Pur_3_years               0.504730           1.000000        -0.342615
# Pur_3_years_Avg                -0.024606          -0.342615         1.000000

# %%
##

# %%
#Your Code Here
sns.regplot(x = "Total_Ad_Res_3_year", y = "Total_Pur_3_years", data = cust_data_new, color= "blue", ci=99, line_kws = {"color" : "red"})

# %% [markdown]
# Ads Response in 3 years have a moderately positive correlation with the total amount of purchase in 3 years

# %% [markdown]
# # 2nd Correlation

# %%
cust_data_new[["Total_Ad_Res_5_year","InAct_First","InAct_Last"]].corr()
# Out:
#                      Total_Ad_Res_5_year  InAct_First  InAct_Last
# Total_Ad_Res_5_year             1.000000     0.878249   -0.214102
# InAct_First                     0.878249     1.000000   -0.082802
# InAct_Last                     -0.214102    -0.082802    1.000000

# %%
sns.regplot(x = "Total_Ad_Res_5_year", y = "InAct_Last", data = cust_data_new, color= "blue", ci=99, line_kws = {"color" : "red"})

# %% [markdown]
# Correlation is negative for last inactive customer to total response to ads in 5 years

# %%
sns.regplot(x = "Total_Ad_Res_5_year", y = "InAct_First", data = cust_data_new, color= "blue", ci=99, line_kws = {"color" : "red"})

# %% [markdown]
# Correlation is positive for first inactive customer to total response to ads in 5 years

# %% [markdown]
# ### Create a Heatmap of correlation between the variables

# %%
#Your Code Here

sns.heatmap(cust_data_new.corr());

# %% [markdown]
# ### Summarize your findings - what have you learned from your insights?

# %% [markdown]
# As a conclusion, we can find that the total advertisement affects the total purchase and engagement of the customers

# %% [markdown]
# ### Find the Numerical Summary statistics for the variables such as mean, median, mode

# %%
cust_data_new.columns
# Out:
# Index(['Potential_Customer', 'C_ID', 'Cust_Last_Purchase', 'Pur_latest',
#        'Pur_3_years_Avg', 'Pur_5_years_Avg', 'Pur_3_years_Avg_Indirect',
#        'InAct_Last', 'InAct_First', 'Status_Cust', 'Status_Latest_Ad', 'Age',
#        'Gender', 'Cust_Prop', 'Cust_Ann_Income', 'Status_CustN',
#        'Total_Pur_3_years', 'Total_Pur_5_years', 'Total_Ad_Res_1_year',
#        'Total_Ad_Res_3_year', 'Total_Ad_Res_5_year'],
#       dtype='object')

# %%
# Take some time to understand these numbers

cust_data_new.describe()
# Out:
#                 C_ID  ...  Total_Ad_Res_5_year
# count    3618.000000  ...          3618.000000
# mean    70151.997236  ...            69.122167
# std     35499.154163  ...            31.064605
# min        12.000000  ...            10.000000
# 25%     50146.500000  ...            43.000000
# 50%     68694.000000  ...            70.000000
# 75%     87779.500000  ...            93.000000
# max    191672.000000  ...           200.000000
#
# [8 rows x 16 columns]

# %% [markdown]
# ### Check for outliers by either plotting box plots or IQR For all numerical variables

# %%
#Your Code Here

#sns.pairplot(data = cust_data_new)

# %%
cust_data_new.Total_Pur_3_years
# Out:
# 0        4
# 1        1
# 2        8
# 3        1
# 4        5
#         ..
# 3613     2
# 3614    11
# 3615    13
# 3616     2
# 3617     4
# Name: Total_Pur_3_years, Length: 3618, dtype: int64

# %%
fig, axes = plt.subplots(6, 2, figsize=(18,22))
fig.suptitle("Boxplot for All Variable")

sns.boxplot(ax=axes[0,0], data=cust_data_new, x="Potential_Customer", y="Cust_Last_Purchase")
sns.boxplot(ax=axes[0,1], data=cust_data_new, x="Potential_Customer", y="Pur_latest")
sns.boxplot(ax=axes[1,0], data=cust_data_new, x="Potential_Customer", y="Pur_3_years_Avg")
sns.boxplot(ax=axes[1,1], data=cust_data_new, x="Potential_Customer", y="Pur_5_years_Avg")
sns.boxplot(ax=axes[2,0], data=cust_data_new, x="Potential_Customer", y="InAct_Last")
sns.boxplot(ax=axes[2,1], data=cust_data_new, x="Potential_Customer", y="InAct_First")
sns.boxplot(ax=axes[3,0], data=cust_data_new, x="Potential_Customer", y="Cust_Ann_Income")
sns.boxplot(ax=axes[3,1], data=cust_data_new, x="Potential_Customer", y="Total_Pur_3_years")
sns.boxplot(ax=axes[4,0], data=cust_data_new, x="Potential_Customer", y="Total_Pur_5_years")
sns.boxplot(ax=axes[4,1], data=cust_data_new, x="Potential_Customer", y="Total_Ad_Res_1_year")
sns.boxplot(ax=axes[5,0], data=cust_data_new, x="Potential_Customer", y="Total_Ad_Res_3_year")
sns.boxplot(ax=axes[5,1], data=cust_data_new, x="Potential_Customer", y="Total_Ad_Res_5_year")
plt.show()

# %%
cust_data_new.to_csv("data_new.csv")

# %%
cust_data_new.dtypes
# Out:
# Potential_Customer            object
# C_ID                           int64
# Cust_Last_Purchase           float64
# Pur_latest                   float64
# Pur_3_years_Avg              float64
# Pur_5_years_Avg              float64
# Pur_3_years_Avg_Indirect     float64
# InAct_Last                     int64
# InAct_First                    int64
# Status_Cust                   string
# Status_Latest_Ad               int64
# Age                          float64
# Gender                      category
# Cust_Prop                   category
# Cust_Ann_Income              float64
# Status_CustN                  object
# Total_Pur_3_years              int64
# Total_Pur_5_years              int64
# Total_Ad_Res_1_year            int64
# Total_Ad_Res_3_year            int64
# Total_Ad_Res_5_year            int64
# dtype: object

# %% [markdown]
# ### Pandas to SQL
#
# #### Load the data into a Sql database, customers
# Hint: Create database with name Customers
# Use pandas to connect and load the dataframe to DATABASE

# %%
pwd
# Out:
# '/content'

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Your Code Here
conn=sqlite3.connect('Customers.db') # Creating the Customers db
                     
Cust=pd.read_csv('data/data_new.csv')                      
Cust.to_sql('Customers_new2',conn)

res = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")
for name in res:
    print(name[0])
# Out:
# Customers_new2

# %%
# %load_ext sql

# %%
conn = sqlite3.connect('Customers.db')

cursor = conn.execute(''' SELECT * FROM Customers_new2 limit 5''')

for row in cursor:
  print(row)
conn.close()
# Out:
# (0, 0, 1, 9946, 5.0, 0.0, 7.5, 7.76, 7.5, 14, 110, 'A', 0, 71.0, 'F', 'H', 65957.0, 'A', 4, 21, 35, 60, 89)
# (1, 1, 1, 87939, 30.0, 25.0, 25.0, 13.0, None, 18, 75, 'A', 1, 7.0, 'M', 'U', 0.0, 'A', 1, 10, 19, 41, 77)
# (2, 2, 0, 88003, None, 15.0, 15.0, 11.25, 14.67, 19, 57, 'S', 1, 79.0, 'F', 'U', 0.0, 'S', 8, 17, 20, 52, 75)
# (3, 3, 1, 188721, 20.0, 20.0, 20.0, 12.45, None, 5, 113, 'A', 0, 73.0, 'F', 'U', 76293.0, 'A', 1, 14, 25, 46, 104)
# (4, 4, 1, 88056, 5.0, 3.0, 4.33, 3.8, 4.0, 17, 118, 'S', 1, 68.0, 'F', 'H', 113663.0, 'S', 5, 22, 19, 40, 87)

# %%
# %sql sqlite:///Customers.db
# Out:
# 'Connected: @Customers.db'

# %%
#Your Code Here
# %%sql
SELECT sqlite_version();
# Out:
#  * sqlite:///Customers.db
# Done.
# [('3.22.0',)]

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';
# Out:
#  * sqlite:///Customers.db
# Done.
# [('Customers_new2',)]

# %% [markdown]
# ### Once you have created a database, use either SQL or Python to query the data and solve these questions

# %%
#Your Code Here
#Your Code Here


# %%sql
-- find out relationships between tables using SQL command
SELECT sql
FROM sqlite_master
WHERE name = "Customers_new2"
# Out:
#  * sqlite:///Customers.db
# Done.
# [('CREATE TABLE "Customers_new2" (\n"index" INTEGER,\n  "Unnamed: 0" INTEGER,\n  "Potential_Customer" INTEGER,\n  "C_ID" INTEGER,\n  "Cust_Last_Purchase ... (348 characters truncated) ... ars" INTEGER,\n  "Total_Pur_5_years" INTEGER,\n  "Total_Ad_Res_1_year" INTEGER,\n  "Total_Ad_Res_3_year" INTEGER,\n  "Total_Ad_Res_5_year" INTEGER\n)',)]

# %%
#Your Code Here

# %% [markdown]
# ### Write a query that returns:

# %% [markdown]
# #### a) What percentage of female customers own a house?

# %%
##Your Code Here
conn = sqlite3.connect('Customers.db')

cursor = conn.execute(''' select (select count(*) from Customers_new2 where Gender ='F' and Cust_Prop ='H'),(select count(*) from Customers_new2)  from Customers_new2 limit 1''')

for row in cursor:
  print(row)
conn.close()
# Out:
# (1028, 3618)

# %%
# %%sql
#
# SELECT (select count(*) from Customers_new2 where Gender ='F' and Cust_Prop ='H')*100/(select count(*) from Customers_new2) as Percentage_of_female_cust_own_a_house
# FROM Customers_new2
# LIMIT 1
# Out:
#  * sqlite:///Customers.db
# Done.
# [(28,)]

# %%
#Your Code Here

##select ((select count(*) from table WHERE gender == 'F')/(count(*)))*100 from table

# %% [markdown]
# #### b) How much is the average salary of these customers?

# %%
#Your Code Here


conn = sqlite3.connect('Customers.db')

cursor = conn.execute(''' SELECT avg(Cust_Ann_Income) FROM Customers_new2 ''')

for row in cursor:
  print(row)
conn.close()
# Out:
# (41608.89441680486,)

# %%
#Your Code Here

# %%sql

SELECT round(avg(Cust_Ann_Income),2) as avg_salary_of_customers
FROM Customers_new2
# Out:
#  * sqlite:///Customers.db
# Done.
# [(41608.89,)]

# %%
# %%sql
#
# SELECT * FROM Customers_new2 Limit 5
# Out:
#  * sqlite:///Customers.db
# Done.
# [(0, 0, 1, 9946, 5.0, 0.0, 7.5, 7.76, 7.5, 14, 110, 'A', 0, 71.0, 'F', 'H', 65957.0, 'A', 4, 21, 35, 60, 89),
#  (1, 1, 1, 87939, 30.0, 25.0, 25.0, 13.0, None, 18, 75, 'A', 1, 7.0, 'M', 'U', 0.0, 'A', 1, 10, 19, 41, 77),
#  (2, 2, 0, 88003, None, 15.0, 15.0, 11.25, 14.67, 19, 57, 'S', 1, 79.0, 'F', 'U', 0.0, 'S', 8, 17, 20, 52, 75),
#  (3, 3, 1, 188721, 20.0, 20.0, 20.0, 12.45, None, 5, 113, 'A', 0, 73.0, 'F', 'U', 76293.0, 'A', 1, 14, 25, 46, 104),
#  (4, 4, 1, 88056, 5.0, 3.0, 4.33, 3.8, 4.0, 17, 118, 'S', 1, 68.0, 'F', 'H', 113663.0, 'S', 5, 22, 19, 40, 87)]

# %%
#Your Code Here

##select avg(Cust_Ann_Income) from table

# %%
#Your Code Here

# %% [markdown]
# ### Write a query that returns:

# %% [markdown]
# #### a) What percentage of purchases are made through external links (indirect buys)?

# %%
#Your Code Here
#Your Code Here

conn=sqlite3.connect('Customers.db') # Creating the Customers db
                     
Cust=pd.read_csv('data/data.csv')                      
Cust.to_sql('Customers_new4',conn)

res = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")
for name in res:
    print(name[0])
# Out:
# Customers_new2
# Customers_new4

# %%
#Your Code Here
conn = sqlite3.connect('Customers.db')

cursor = conn.execute(''' SELECT * FROM Customers_new2 limit 5''')

for row in cursor:
  print(row)
conn.close()
# Out:
# (0, 0, 1, 9946, 5.0, 0.0, 7.5, 7.76, 7.5, 14, 110, 'A', 0, 71.0, 'F', 'H', 65957.0, 'A', 4, 21, 35, 60, 89)
# (1, 1, 1, 87939, 30.0, 25.0, 25.0, 13.0, None, 18, 75, 'A', 1, 7.0, 'M', 'U', 0.0, 'A', 1, 10, 19, 41, 77)
# (2, 2, 0, 88003, None, 15.0, 15.0, 11.25, 14.67, 19, 57, 'S', 1, 79.0, 'F', 'U', 0.0, 'S', 8, 17, 20, 52, 75)
# (3, 3, 1, 188721, 20.0, 20.0, 20.0, 12.45, None, 5, 113, 'A', 0, 73.0, 'F', 'U', 76293.0, 'A', 1, 14, 25, 46, 104)
# (4, 4, 1, 88056, 5.0, 3.0, 4.33, 3.8, 4.0, 17, 118, 'S', 1, 68.0, 'F', 'H', 113663.0, 'S', 5, 22, 19, 40, 87)

# %%
conn = sqlite3.connect('Customers.db')

cursor = conn.execute(''' SELECT b.Pur_3_years, b.Pur_5_years, b.Pur_3_years_Indirect, b.Pur_5_years_Indirect, a.Total_Pur_3_years, a.Total_Pur_5_years FROM Customers_new2 a join Customers_new4 b on a.C_ID = b.C_ID limit 5''')

for row in cursor:
  print(row)
conn.close()
# Out:
# (2, 17, 2, 4, 4, 21)
# (2, 17, 2, 4, 4, 21)
# (1, 7, 0, 3, 1, 10)
# (1, 7, 0, 3, 1, 10)
# (5, 12, 3, 5, 8, 17)

# %%
conn = sqlite3.connect('Customers.db')

cursor = conn.execute(''' SELECT sum(b.Pur_3_years_Indirect + b.Pur_5_years_Indirect) ,sum(a.Total_Pur_3_years + a.Total_Pur_5_years) FROM Customers_new2 a join Customers_new4 b on a.C_ID = b.C_ID''')

for row in cursor:
  print(row)
conn.close()
# Out:
# (34703, 98624)

# %%
#Your Code Here

# %%sql

SELECT (sum(b.Pur_3_years_Indirect + b.Pur_5_years_Indirect)*100/sum(a.Total_Pur_3_years + a.Total_Pur_5_years)) as percentage_of_purchases_are_made_through_external_links 
FROM Customers_new2 a 
join Customers_new4 b on a.C_ID = b.C_ID
# Out:
#  * sqlite:///Customers.db
# Done.
# [(35,)]

# %% [markdown]
# #### b) How many purchases have been made by new buyers through external links?

# %%
#Your Code Here
#Your Code Here


conn = sqlite3.connect('Customers.db')

cursor = conn.execute(''' SELECT sum(Pur_3_years_Indirect + Pur_5_years_Indirect) FROM Customers_new4 where Status_Cust = "N"''')

for row in cursor:
  print(row)
conn.close()
# Out:
# (729,)

# %%
#Your Code Here

#Your Code Here

# %%sql

SELECT sum(Pur_3_years_Indirect + Pur_5_years_Indirect) as purchases_by_new_buyers_ext_link
FROM  Customers_new4
where Status_Cust = "N"
# Out:
#  * sqlite:///Customers.db
# Done.
# [(729,)]

# %% [markdown]
# ### Write a query that calculate:

# %% [markdown]
# #### The average amount of purchases that have been made by Star Buyers?

# %%
#Your Code Here
#Your Code Here


conn = sqlite3.connect('Customers.db')

cursor = conn.execute(''' SELECT avg(Pur_3_years + Pur_5_years) FROM Customers_new4 where Status_Cust="S"''')

for row in cursor:
  print(row)
conn.close()
# Out:
# (24.85919055649241,)

# %%
#Your Code Here
#Your Code Here

#Your Code Here

#Your Code Here

# %%sql

SELECT round(avg(Pur_3_years + Pur_5_years),2) as avg_purchases_by_star_buyers
FROM  Customers_new4 b
where Status_Cust = "S"
# Out:
#  * sqlite:///Customers.db
# Done.
# [(24.86,)]
